# %%
# read the csv file

# %%
import pandas as pd 
import geopy.distance
import numpy as np
import json
import requests
df = pd.read_csv('google_results.csv')

# %%
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
def get_ngrams(text, n ):
    n_grams = ngrams(word_tokenize(text), n)
    return [ ' '.join(grams) for grams in n_grams]

# %%
df = pd.read_csv('google_results.csv')

# %%
df['dist'].describe()
# Out:
# count    1059.000000
# mean      906.620667
# std      1210.789735
# min         0.000000
# 25%        98.742242
# 50%       399.016227
# 75%      1189.658476
# max      9057.069734
# Name: dist, dtype: float64

# %%
df_google = pd.read_csv('updated_google.csv')

# %%
df_google.describe()
# Out:
#         Unnamed: 0           ID         dist  google_dist
# count  1059.000000  1059.000000  1059.000000  1059.000000
# mean    529.000000  1649.679887   906.620667     0.922077
# std     305.851271   357.155874  1210.789735     1.085531
# min       0.000000  1034.000000     0.000000     0.000000
# 25%     264.500000  1344.000000    98.742242     0.232967
# 50%     529.000000  1646.000000   399.016227     0.573738
# 75%     793.500000  1963.500000  1189.658476     1.164428
# max    1058.000000  2309.000000  9057.069734     7.150097

# %%
sent = df['Where_'][41]

# %%
sent
# Out:
# 'ביפו קרוב לים קרוב למלביה לא ממש רחוב ספציפי יותר אזור'

# %%
df = bauman_df_Gir

# %%
min_dists_array = []
for _id in df.index:
    address = df['Where'][_id]
    name_place = df['Location_Hebrew'][_id]
    name_place = name_place + "בתל אביב"
    x = requests.get(f'https://maps.googleapis.com/maps/api/geocode/json?address={name_place}&language=iw&key=AIzaSyDb7Hf2sRwzf5k0MDM-z1Jll5-h92AADr8')
    f = json.loads(x.text)
    first_location = f['results'][0]['geometry']['location']
    place_coords = (first_location['lat'], first_location['lng'])
    list_places = get_list_places(address)
    min_dist = findTheMinDist(list_places, place_coords)
    print(min_dist)
    min_dists_array.append(min_dist)
# Out:
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# 0.2806249850174091
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# 0.2913678981310486
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# 0.9499677578705886
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# 0.2913678981310486
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# ...

# %%
len(min_dists_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-769d52f74ce2> in <module>
# ----> 1 len(min_dists_array)
#
# NameError: name 'min_dists_array' is not defined

# %%
import requests
from requests.structures import CaseInsensitiveDict

def IsInTelAviv(location):
    lat, lon = location
    url = f'https://api.geoapify.com/v1/geocode/reverse?lat={lat}&lon={lon}&apiKey=b7eeb3936d1b4df8aff2c1fcbae3857a'
    headers = CaseInsensitiveDict()
    headers["Accept"] = "application/json"
    resp = requests.get(url, headers=headers)
    output = json.loads(resp.text)
    city_out = output['features'][0]['properties']['city']
    return city_out == 'Tel Aviv'

# %%
f['features'][0]['properties']['city']
# Out:
# 'Jerusalem'

# %%
out = IsInTelAviv(('32.0804846','34.7806198' ))
# Out:
# Tel Aviv

# %%
out
# Out:
# True

# %%
out

# %%
f = json.loads(x.text)
f
# Out:
# {'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account',
#  'results': [],
#  'status': 'REQUEST_DENIED'}

# %%
def checkIfInTelAviv(f):
    city = []
    city.append(f['results'][0]['address_components'][1]['long_name'])
    city.append(f['results'][0]['address_components'][0]['long_name'])
    city.append(f['results'][0]['address_components'][2]['long_name'])
    city.append(f['results'][0]['address_components'][3]['long_name'])
    count = city.count('תל אביב-יפו') 
    return count >= 1

# %%
# def get_list_places(address):
#     list_places = []
#     list_ngrams = get_ngrams(address, 2)
#     try:
#         for place in list_ngrams:
#             x = requests.get(f'https://maps.googleapis.com/maps/api/geocode/json?address={place}&language=iw&key=AIzaSyDb7Hf2sRwzf5k0MDM-z1Jll5-h92AADr8')
#             f = json.loads(x.text)
#             print(place)
#             print(f)
#             first_location = f['results'][0]['geometry']['location']
#             print(first_location)
#             loc = (first_location['lat'], first_location['lng'])
#             list_places.append(loc)
#     except:
#          print("An exception occurred")
#     return list_places

def get_list_places(address):
    list_places = []
    list_unigrams = np.array(get_ngrams(address, 1))
    list_trigrams = np.array(get_ngrams(address, 3))
    list_ngrams = get_ngrams(address, 2)
    l = [*list_trigrams, *list_ngrams, *list_unigrams]
    TEL_AVIV_CENTER = ('32.0853','34.7818')
#     try:
    for place in l:
        x = requests.get(f'https://maps.googleapis.com/maps/api/geocode/json?address={place}&language=iw&key=AIzaSyDb7Hf2sRwzf5k0MDM-z1Jll5-h92AADr8')
        f = json.loads(x.text)
        try:
            first_location = f['results'][0]['geometry']['location']
            loc = (first_location['lat'], first_location['lng'])
            if checkIfInTelAviv(f):
                list_places.append(loc)
        except:
             print("An exception occurred")
    if len(list_places) == 0:
        list_places.append(TEL_AVIV_CENTER)
    return list_places

# %%
sent
# Out:
# 'ביפו קרוב לים קרוב למלביה לא ממש רחוב ספציפי יותר אזור'

# %%
place = 'לחפש שוק'

# %%
x = requests.get(f'https://maps.googleapis.com/maps/api/geocode/json?address={place}&language=iw&key=AIzaSyDb7Hf2sRwzf5k0MDM-z1Jll5-h92AADr8')
f = json.loads(x.text)

# %%
list_places = get_list_places(sent)
# Out:
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred

# %%
list_places
# Out:
# [(32.0504707, 34.7548737), (32.0565643, 34.778778), (32.0700798, 34.7702002)]

# %%
df = pd.read_csv('google_results.csv')

# %%
df
# Out:
#       Unnamed: 0    ID        dist            Hebrew  \
# 0              0  1034  900.100828        כיכר מסריק
# 1              1  1069  440.845349        כיכר מסריק
# 2              2  1083  357.828820        כיכר מסריק
# 3              3  1150  230.218671        כיכר מסריק
# 4              4  1169  240.579423        כיכר מסריק
# ...          ...   ...         ...               ...
# 1054        1054  2177   25.851829  לונדון מיניסטורס
# 1055        1055  2201    0.000000  לונדון מיניסטורס
# 1056        1056  2236  378.743561  לונדון מיניסטורס
# 1057        1057  2262  155.452880  לונדון מיניסטורס
# 1058        1058  2291   94.031312  לונדון מיניסטורס
#
#                                                  Where_  \
# 0                           ליד רחוב אבן גבירול לב העיר
# 1                 בקרבת כיכר רבין וכיוון דיזינגהוף סנטר
# 2                          בין כיכר רבין לכיכר דיזינגוף
# 3                                         ליד כיכר רבין
# ...

# %%
df['google_unigrams_bigrams_unigrams'] = min_dists_array

# %%
df['google_unigrams_bigrams_unigrams'].describe()
# Out:
# count    1059.000000
# mean        0.741273
# std         0.951917
# min         0.000000
# 25%         0.141744
# 50%         0.406951
# 75%         0.929970
# max         7.731040
# Name: google_unigrams_bigrams_unigrams, dtype: float64

# %%
df = pd.read_csv('google_bigrams_trigrams.csv')

# %%
df.to_csv('google_bigrams_trigrams_unigrams.csv',index=False)

# %%
df['google_girams_trigramd'].describe()
# Out:
# count    1059.000000
# mean        0.758298
# std         0.936455
# min         0.000000
# 25%         0.158717
# 50%         0.423227
# 75%         0.941236
# max         7.731040
# Name: google_girams_trigramd, dtype: float64

# %%
df = pd.read_csv('google_results.csv')

# %%
df['dist'].describe()
# Out:
# count    1059.000000
# mean      906.620667
# std      1210.789735
# min         0.000000
# 25%        98.742242
# 50%       399.016227
# 75%      1189.658476
# max      9057.069734
# Name: dist, dtype: float64

# %%
df.to_csv('google_bigrams_trigrams.csv',index=False)

# %%
df['google_dist']
# Out:
# 0        0.611432
# 1        0.291368
# 2        0.291368
# 3        0.291368
# 4        0.291368
#           ...
# 1054      1.58387
# 1055            0
# 1056     0.613318
# 1057    0.0829601
# 1058      9136.23
# Name: google_dist, Length: 1059, dtype: object

# %%
def findTheMinDist(list_places, place_coords):
    dists = [geopy.distance.distance(temp_place, place_coords).km for temp_place in list_places]
    return min(dists)

# %%
findTheMinDist(list_places, place_coords)
# Out:
# 0.6133176914834263

# %%
list_places
# Out:
# [(32.0748279, 34.7755836)]

# %% [markdown]
# # תיאורי הולכה

# %%
indictive = ['הולכים']

# %%
df = pd.read_csv('google_results.csv')

# %%
df_walk = df[df['Where_'].str.contains('|'.join(indictive))]

# %%
df_walk.count()
# Out:
# Unnamed: 0    37
# ID            37
# dist          37
# Hebrew        37
# Where_        37
# geometry      37
# dtype: int64

# %%
#using google maps api \
import googlemaps 
API = 'AIzaSyDb7Hf2sRwzf5k0MDM-z1Jll5-h92AADr8'
map_client = googlemaps.Client(API)

# %%
place_1 = df['Where_'][5]
place_1
# Out:
# 'מדובר בכיכר בין כיכר רבין לדיזינגוף סנטר הכיכר מוקפת בנייני מגורים נמצאת ממש על הגבול הדרומי של כיכר רבין'

# %%
response = map_client.geocode('יחסית בצפון הישן של העיר בצפון אבן גבירול')
response
# Out:
# [{'address_components': [{'long_name': 'Tel Aviv-Yafo',
#     'short_name': 'Tel Aviv-Yafo',
#     'types': ['locality', 'political']},
#    {'long_name': 'Tel Aviv District',
#     'short_name': 'Tel Aviv District',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Israel',
#     'short_name': 'IL',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Tel Aviv-Yafo, Israel',
#   'geometry': {'bounds': {'northeast': {'lat': 32.146611, 'lng': 34.8519761},
#     'southwest': {'lat': 32.029252, 'lng': 34.7425159}},
#    'location': {'lat': 32.0852999, 'lng': 34.78176759999999},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 32.146611, 'lng': 34.8519761},
#     'southwest': {'lat': 32.029252, 'lng': 34.7425159}}},
#   'place_id': 'ChIJH3w7GaZMHRURkD-WwKJy-8E',
#   'types': ['locality', 'political']}]

# %%
_index = df_corners.index

# %%
df['Where_']
# Out:
# 0                             ליד רחוב אבן גבירול לב העיר
# 1                   בקרבת כיכר רבין וכיוון דיזינגהוף סנטר
# 2                            בין כיכר רבין לכיכר דיזינגוף
# 3                                           ליד כיכר רבין
# 4                                 מרכז העיר ליד כיכר רבין
#                               ...
# 1054                  בפינת הרחובות שאול המלך ואבן גבירול
# 1055    לונדון מיניסטור נמצא בשדרות שאול המלך פינת אבן...
# 1056                           אבן גבירול קרוב לכיכר רבין
# 1057    פינת אבן גבירול ושאול המלך יש בניין עם סופר מר...
# 1058          מרכז מסחר בפינת הרחובות שאול המלךאבן גבירול
# Name: Where_, Length: 1059, dtype: object

# %%
df = pd.Series(' '.join(df['Where_']).lower().split()).value_counts()[:100]

# %%
df[:20]
# Out:
# אביב        473
# תל          397
# ליד         239
# רחוב        225
# על          199
# של          151
# נמצא        127
# בין         111
# העיר        108
# מרכז        101
# דרום         90
# גבירול       82
# הים          81
# קרוב         76
# השלום        72
# יפו          67
# אבן          65
# במרכז        65
# ברחוב        64
# דיזינגוף     64
# dtype: int64

# %% [markdown]
# # מציאת פינות

# %%
corner_words = [ 'חיבור','בפינה','פינת','צומת','פינה']

# %%
df_corner = df[df['Where_'].str.contains('|'.join(corner_words))]

# %%
df_corner
# Out:
#       Unnamed: 0    ID        dist            Hebrew  \
# 13            13  1439  240.579423        כיכר מסריק
# 20            20  1639    0.000000        כיכר מסריק
# 28            28  1940  240.579423        כיכר מסריק
# 74            74  2193  619.943508       שוק הפשפשים
# 84            84  1203  810.568680     כיכר דיזינגוף
# ...          ...   ...         ...               ...
# 1053        1053  2153   26.308001  לונדון מיניסטורס
# 1054        1054  2177   25.851829  לונדון מיניסטורס
# 1055        1055  2201    0.000000  לונדון מיניסטורס
# 1057        1057  2262  155.452880  לונדון מיניסטורס
# 1058        1058  2291   94.031312  לונדון מיניסטורס
#
#                                                  Where_  \
# 13    בפינה הדרום מערבית של כיכר רבין יוצא רחוב קינג...
# 20    כיכר מוארכת וירוקה ברחוב מסריק סמוך לצומת מסרי...
# 28    דרומית לכיכר רבין ממשיכים בכביש מהפינה הדרומית...
# 74                       בחיבור יפו תל אביב לא רחוק מים
# ...

# %% [markdown]
# # מרחקים לפי המודל של באומן - שינוי האבלאוציה

# %%
bauman_df = pd.read_csv('GIRIt_data.csv')

# %%
bauman_df
# Out:
#         ID    TimeStamp                                              Where  \
# 0     1034    46638.050                        ליד רחוב אבן גבירול לב העיר
# 1     1069   397525.600                בקרבת כיכר רבין וכיוון דיזנגוף סנטר
# 2     1083    61423.700                        בין כיכר רבין לכיכר דיזנגוף
# 3     1150    37374.690                                      ליד כיכר רבין
# 4     1232   171875.800  מדובר בכיכר בין כיכר רבין לדיזנגוף סנטר הכיכר ...
# ...    ...          ...                                                ...
# 1077  1997   158269.000                                  על רחוב קינג גורג
# 1078  2283  1679789.595    גן עירוני בדרום תל אביב תחום בין רחוב קינג גורג
# 1079  2309   684460.700               על רחוב טשרניחובסקי ליד דיזנגוף סנטר
# 1080  2262   356630.500  פינת אבן גבירול ושאול המלך יש בניין עם סופר מר...
# 1081  2291  2930201.745        מרכז מסחר בפינת הרחובות שאול המלךאבן גבירול
#
# ...

# %%
from shapely.geometry import Polygon, Point
from shapely import wkt

# %%
Girit_no_null = bauman_df.GIR_geometry.dropna()
list_index = list(bauman_df.GIR_geometry.dropna().index)

# %%
geo_point = [wkt.loads(Girit_no_null[i]).centroid for i in Girit_no_null.index]

# %%
bauman_df = bauman_df[bauman_df.index.isin(list_index)].reset_index(drop = True)
bauman_df['geo_point'] = geo_point

# %%
list_points = list(bauman_df.GIR_geometry.dropna().index)

# %%
bauman_df_Gir = bauman_df[bauman_df.index.isin(list_points)].reset_index(drop = True)

# %%
index_no_nul_google = list(bauman_df_Gir.Google_geometry.dropna().index)

# %%
bauman_df_Gir = bauman_df_Gir[bauman_df_Gir.index.isin(index_no_nul_google)].reset_index(drop = True)

# %%
dists = [wkt.loads(bauman_df_Gir.Location_geometry[i]).distance(bauman_df_Gir.geo_point[i]) for i in range(len(index_no_nul_google))]

# %%
bauman_df_Gir['GIR_Distance'] = dists

# %%
bauman_df_Gir.columns
# Out:
# Index(['ID', 'TimeStamp', 'Where', 'What', 'UserID', 'Age', 'Gender',
#        'Education', 'City', 'User_clearness', 'User_knows_TLV', 'User_comment',
#        'LocationID', 'Location_Hebrew', 'Location_English', 'Location_Type',
#        'Location_Area', 'Location_geometry', 'Google_distance',
#        'Google_geometry', 'GIR_distance', 'GIR_geometry', 'geo_point',
#        'GIR_Distance'],
#       dtype='object')

# %%
bauman_df_Gir.describe()
# Out:
#                 ID     TimeStamp      UserID         Age      Gender  \
# count   290.000000  2.900000e+02  290.000000  290.000000  290.000000
# mean   1637.844828  5.510942e+05  426.913793   30.582759    1.400000
# std     358.957641  1.911340e+06  107.118097   10.266773    0.490745
# min    1038.000000  4.788100e+04  244.000000   19.000000    1.000000
# 25%    1339.250000  1.708695e+05  342.000000   24.000000    1.000000
# 50%    1621.500000  3.024900e+05  420.000000   28.000000    1.000000
# 75%    1958.000000  5.139468e+05  529.750000   33.000000    2.000000
# max    2308.000000  2.329741e+07  606.000000   83.000000    2.000000
#
#         Education  User_clearness  User_knows_TLV  LocationID  Location_Area  \
# count  290.000000      290.000000      290.000000  290.000000     290.000000
# mean     1.706897        1.789655        1.717241   83.279310  154405.151645
# std      0.478197        1.506811        1.402930    8.916059  209521.549242
# ...

# %%
bauman_df_Gir.to_csv('New_GIRIt_centroid.csv')

# %% [markdown]
# # make a merged dataframe

# %%
data_ngrams = pd.read_csv('google_bigrams_trigrams_unigrams.csv')

# %%
data_ngrams = data_ngrams[data_ngrams['Where_'].isin(bauman_df_Gir.Where)].reset_index(drop = True)

# %%
data_ngrams.describe()
# Out:
#         Unnamed: 0           ID         dist  google_unigrams_bigrams_unigrams
# count   261.000000   261.000000   261.000000                        261.000000
# mean    502.310345  1650.540230  1032.291798                          0.759313
# std     267.948860   362.257032  1159.050969                          0.962445
# min       7.000000  1038.000000     0.000000                          0.000000
# 25%     276.000000  1342.000000   169.092199                          0.187821
# 50%     526.000000  1653.000000   558.534556                          0.477262
# 75%     742.000000  1976.000000  1753.839707                          0.935482
# max    1057.000000  2283.000000  6009.873992                          7.731040

# %%
data_ngrams.describe()
# Out:
#         Unnamed: 0           ID         dist  google_unigrams_bigrams_unigrams
# count  1059.000000  1059.000000  1059.000000                       1059.000000
# mean    529.000000  1649.679887   906.620667                          0.741273
# std     305.851271   357.155874  1210.789735                          0.951917
# min       0.000000  1034.000000     0.000000                          0.000000
# 25%     264.500000  1344.000000    98.742242                          0.141744
# 50%     529.000000  1646.000000   399.016227                          0.406951
# 75%     793.500000  1963.500000  1189.658476                          0.929970
# max    1058.000000  2309.000000  9057.069734                          7.731040

# %%
bauman_df
# Out:
#        ID    TimeStamp                                              Where  \
# 0    1232   171875.800  מדובר בכיכר בין כיכר רבין לדיזנגוף סנטר הכיכר ...
# 1    1242   183084.000  שתי דקות הליכה דרום מזרח מכיכר רבין וגם לא רחו...
# 2    1271    59399.700          יחסית בצפון הישן של העיר בצפון אבן גבירול
# 3    1316   161111.700      ברחוב מסריק בצמוד יחסית לכיכר רבין מדרום מערב
# 4    1439   153434.000  בפינה הדרום מערבית של כיכר רבין יוצא רחוב קינג...
# ..    ...          ...                                                ...
# 303  1907   164901.600           מרכז תל אביב רחוב דיזנגוף פינת קינג גורג
# 304  1960   364837.300                דרומית לכיכר דיזנגוף על הרחוב הראשי
# 305  2308   477368.700              לב העיר על רחוב קינג גורגפינת דיזנגוף
# 306  2283  1679789.595    גן עירוני בדרום תל אביב תחום בין רחוב קינג גורג
# 307  2262   356630.500  פינת אבן גבירול ושאול המלך יש בניין עם סופר מר...
#
#                                                   What  UserID  Age  Gender  \
# ...

# %%
data_girit = pd.read_csv('GIRIt_data.csv')[['Where','GIR_distance', 'GIR_geometry']]

# %%
old_data =  pd.read_csv('google_results.csv')

# %%
old_data['GIRIt'] = data_girit['GIR_distance']

# %%
for row in old_data.iterrows():
    if old_data['Where_'] == data_girit['Where']:
        print("hh")
        old_data['GIRIt'] = data_girit['GIR_distance']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-590-1fc65a840e03> in <module>
#       1 for row in old_data.iterrows():
# ----> 2     if old_data['Where_'] == data_girit['Where']:
#       3         print("hh")
#       4         old_data['GIRIt'] = data_girit['GIR_distance']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     363
#     364         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 365             raise ValueError("Can only compare identically-labeled Series objects")
#     366
# ...

# %%
matching_id = data_girit.Where.isin(old_data.Where_)

# %%
new_df = data_girit.loc[matching_id, :]

# %%
new_df
# Out:
#                                                   Where  GIR_distance  \
# 0                           ליד רחוב אבן גבירול לב העיר           NaN
# 3                                         ליד כיכר רבין           NaN
# 6             יחסית בצפון הישן של העיר בצפון אבן גבירול    713.087125
# 8                                     מרכז העיר תת אביב           NaN
# 9         ברחוב מסריק בצמוד יחסית לכיכר רבין מדרום מערב      0.000000
# ...                                                 ...           ...
# 1071                      מערבית לאיילון בקו מחלף השלום   2499.561399
# 1073               לא יודעת לתאר כל כך מרכז תל אביב כזה           NaN
# 1078    גן עירוני בדרום תל אביב תחום בין רחוב קינג גורג   2129.308533
# 1080  פינת אבן גבירול ושאול המלך יש בניין עם סופר מר...      0.000000
# 1081        מרכז מסחר בפינת הרחובות שאול המלךאבן גבירול           NaN
#
#                                            GIR_geometry
# 0                                                   NaN
# ...

# %%
old_data.drop_duplicates()
# Out:
#       Unnamed: 0    ID        dist            Hebrew  \
# 0              0  1034  900.100828        כיכר מסריק
# 1              1  1069  440.845349        כיכר מסריק
# 2              2  1083  357.828820        כיכר מסריק
# 3              3  1150  230.218671        כיכר מסריק
# 4              4  1169  240.579423        כיכר מסריק
# ...          ...   ...         ...               ...
# 1054        1054  2177   25.851829  לונדון מיניסטורס
# 1055        1055  2201    0.000000  לונדון מיניסטורס
# 1056        1056  2236  378.743561  לונדון מיניסטורס
# 1057        1057  2262  155.452880  לונדון מיניסטורס
# 1058        1058  2291   94.031312  לונדון מיניסטורס
#
#                                                  Where_  \
# 0                           ליד רחוב אבן גבירול לב העיר
# 1                 בקרבת כיכר רבין וכיוון דיזינגהוף סנטר
# 2                          בין כיכר רבין לכיכר דיזינגוף
# 3                                         ליד כיכר רבין
# ...

# %% [markdown]
# # Exploration of Bauman Data

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('GIRIt_data.csv')

# %%
df = df[['UserID', 'Age']]

# %%
plt.hist(df.groupby('UserID').mean()['Age'])
# Out:
# (array([101.,  73.,  34.,   7.,   7.,   2.,   7.,   1.,   1.,   3.]),
#  array([18., 25., 32., 39., 46., 53., 60., 67., 74., 81., 88.]),
#  <BarContainer object of 10 artists>)

# %%
df = pd.read_csv('GIRIt_data.csv')

# %%
plt.hist(df[['UserID', 'Gender']].groupby('UserID').max()['Gender'])
# Out:
# (array([  1.,   0.,   0.,   0.,   0., 133.,   0.,   0.,   0., 102.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)
